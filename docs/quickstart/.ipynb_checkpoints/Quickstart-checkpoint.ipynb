# %% [markdown]
# # Quickstart

# %%
# Import the usual libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
# Import sarkas
from sarkas.processes import Simulation, PostProcess

plt.style.use('MSUstyle')
# Create the file path to the YAML input file
example_directory = os.path.join('..',
                                 os.path.join('sarkas','examples'))

input_file_name = os.path.join(example_directory, 'egs_cgs.yaml')
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
# Initialize the Simulation class
sim = Simulation(input_file_name)
# Setup the simulation's parameters
sim.setup(read_yaml=True)
# Run the simulation
sim.run()
# Out:
#  _______              __
# |     __|.---.-.----.|  |--.---.-.-----.
# |__     ||  _  |   _||    <|  _  |__ --|
# |_______||___._|__|  |__|__|___._|_____|
# 0it [00:00, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
# An open-source pure-python molecular dynamics code for non-ideal plasmas.
#
#
# ----------------- Simulation -----------------------
#
# Job ID:  egs
# Job directory:  Simulations/egs_langevin
# Equilibration dumps directory:  Simulations/egs_langevin/Equilibration/dumps
# Production dumps directory:  Simulations/egs_langevin/Production/dumps
#
# Units:  mks
# Total No. of particles =  1000
#
# Particle Species:
# No. of species =  1
# Species 1 : Li
# 	Species ID: 0
# 	No. of particles = 1000
# 	Number density = 4.450883e+28 [N/m^3]
# 	Mass = 1.152580e-26 [kg]
# 	Charge = 1.602177e-19 [C]
# 	Temperature = 6.000000e+02 [K]
#
# Lengths scales:
# Wigner-Seitz radius = 1.750472e-10 [m]
# No. of non-zero box dimensions =  3
# Box length along x axis = 1.611992e+01 a_ws = 2.821746e-09 [m]
# Box length along y axis = 1.611992e+01 a_ws = 2.821746e-09 [m]
# Box length along z axis = 1.611992e+01 a_ws = 2.821746e-09 [m]
# The remaining lengths scales are given in [m]
#
# Boundary conditions: periodic
#
# Thermostat:  Berendsen
# Berendsen Relaxation rate: 0.100
# Thermostating Temperatures:  600
#
# Potential:  EGS
# kappa = 2.8429e+00
# lambda_TF = 6.1573e-11
# nu = 6.4844e-01
# Exponential decay:
# lambda_p = 2.7779e-11
# lambda_m = 5.4951e-11
# alpha = 1.6865e+00
# Theta = 1.1290e-02
# b = 1.0000e+00
# Gamma_eff = 159.10
#
# Algorithm:  PP
# rcut = 5.7127 a_ws = 1.000000e-09 [m]
# No. of PP cells per dimension =  2,  2,  2
# No. of particles in PP loop =   1201
# No. of PP neighbors per particle =    186
# Tot Force Error = 1.826430e-07
#
# Integrator:  Verlet_Langevin
#
# Time scales:
# Time step = 9.450000e-17 [s]
# (total) plasma frequency = 1.058092e+14 [Hz]
# wp dt = 0.0100
# No. of equilibration steps = 0 ~ 0 wp T_eq
# snapshot interval = 1 = 0.010 wp T_snap
# No. of post-equilibration steps = 5000 ~ 49 wp T_prod
# snapshot interval = 10 = 0.100 wp T_snap
#
# Potential Initialization Time: 0 sec 14 msec 456 usec 786 nsec
#
# Particles Initialization Time: 0 sec 0 msec 404 usec 42 nsec
#
# Total Simulation Initialization Time: 0 sec 14 msec 456 usec 786 nsec
#
# ------------- Equilibration -------------
#
# Equilibration Time: 0 sec 3 msec 519 usec 979 nsec
#
# ------------- Production -------------
# 100%|██████████| 5000/5000 [01:24<00:00, 59.14it/s]
# Production Time: 0 hrs 1 min 24 sec
#
# Total Time: 0 hrs 1 min 24 sec

# %%
# Initialize the Postprocessing class
postproc = PostProcess(input_file_name)
postproc.setup(read_yaml=True)

# %%
# Initialize and run the Thermodynamics class
postproc.therm.setup(postproc.parameters)
postproc.therm.temp_energy_plot(postproc, phase='production', show=True)
# Out:
# /home/luciano/anaconda3/envs/sarkas/lib/python3.7/site-packages/sarkas_md-0.1.0-py3.7.egg/sarkas/tools/observables.py:1690: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
# Initialize the Pair Distribution Function class
postproc.rdf.setup(postproc.parameters)
postproc.rdf.save()
postproc.rdf.plot(show=True)
# Out:
# /home/luciano/anaconda3/envs/sarkas/lib/python3.7/site-packages/sarkas_md-0.1.0-py3.7.egg/sarkas/tools/observables.py:1122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
